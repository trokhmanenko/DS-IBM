# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ## Introduction
# This notebook provides an overview of essential data science tools and languages, illustrating how these tools are applied in the field. Understanding these basics is crucial for anyone aspiring to become a data scientist.

# %% [markdown]
# **Objectives:**
#
# - List popular languages for Data Science.
# - Identify key libraries used in Data Science.
# - Demonstrate basic operations with Python (e.g., arithmetic operations, data type conversions).

# %% [markdown]
# ## Data Science Languages
# Some of the popular languages that Data Scientists use are:
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Scala
# 6. Julia
# 7. MATLAB
# 8. C++

# %% [markdown]
# ## Data Science Libraries
# Some of the commonly used libraries used by Data Scientists include:
#
# ### Python Libraries
# 1. Pandas: Data manipulation and analysis
# 2. NumPy: Numerical computing
# 3. Scikit-learn: Machine learning
# 4. TensorFlow: Deep learning
# 5. PyTorch: Deep learning
# 6. Matplotlib: Data visualization
# 7. Seaborn: Data visualization
# 8. NLTK: Natural Language Processing
#
# ### R Libraries
# 1. ggplot2: Data visualization
# 2. dplyr: Data manipulation
# 3. tidyr: Data tidying
# 4. caret: Machine learning
# 5. shiny: Web apps for R
#
# ### JavaScript
# 1. TensorFlow.js: Machine learning in JavaScript
# 2. R-js: R programming in JavaScript
#
# ### Scala
# 1. Apache Spark: Big data processing framework
# 2. MLlib: Machine learning library in Spark
# 3. GraphX: Graph processing library in Spark
# 4. Spark Streaming: Real-time data processing

# %% [markdown]
# ## Data Science Tools
#
# | Data Science Tools  |
# |---------------------|
# | JupyterLab          |
# | Anaconda Navigator  |
# | RStudio             |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This a simple arithmetic expression to mutiply then add integers
(3*4)+5
# Out:
# 17

# %%
def convert_minutes_to_hours(minutes):
    """Converts minutes to hours."""
    return minutes / 60

# This will convert 200 minutes to hours by diving by 60
convert_minutes_to_hours(200)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Dmitrii Trokhmanenko
